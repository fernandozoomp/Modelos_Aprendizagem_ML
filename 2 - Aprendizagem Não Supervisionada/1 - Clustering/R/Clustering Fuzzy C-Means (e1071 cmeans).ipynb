# %% [markdown]
# ### Clustering Fuzzy C-Means

# %%
library(e1071)

# %%
cluster = cmeans(iris[,1:4], center=3)
cluster
# Out:
# Fuzzy c-means clustering with 3 clusters
#
# Cluster centers:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1     6.775081    3.052403     5.646869   2.0535804
# 2     5.888991    2.761090     4.364037   1.3973588
# 3     5.003966    3.414086     1.482820   0.2535484
#
# Memberships:
#                   1            2           3
#   [1,] 0.0010720476 0.0023043741 0.996623578
#   [2,] 0.0074975677 0.0166483582 0.975854074
#   [3,] 0.0064143346 0.0137587492 0.979826916
#   [4,] 0.0101070243 0.0224635025 0.967429473
#   [5,] 0.0017679418 0.0037616697 0.994470388
#   [6,] 0.0206187883 0.0448038331 0.934577379
#   [7,] 0.0065042612 0.0140030380 0.979492701
#   [8,] 0.0001411978 0.0003115117 0.999547291
#   [9,] 0.0219014789 0.0477148762 0.930383645
#  [10,] 0.0053412733 0.0119346076 0.982724119
#  [11,] 0.0102005747 0.0217556890 0.968043736
#  [12,] 0.0024309104 0.0054313579 0.992137732
#  [13,] 0.0091767452 0.0201813694 0.970641885
# ...

# %%
summary(cluster)
# Out:
#             Length Class  Mode
# centers      12    -none- numeric
# size          3    -none- numeric
# cluster     150    -none- numeric
# membership  450    -none- numeric
# iter          1    -none- numeric
# withinerror   1    -none- numeric
# call          3    -none- call

# %%
table(iris$Species, cluster$cluster)
# Out:
#
#               1  2  3
#   setosa      0  0 50
#   versicolor  3 47  0
#   virginica  37 13  0
